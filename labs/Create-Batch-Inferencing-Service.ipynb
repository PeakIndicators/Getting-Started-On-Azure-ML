# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# With the latest version of the SDK installed, now you're ready to connect to your workspace.
#
# **Note:** If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.23.0 to work with lg-aml-dev

# %% [markdown]
# ## Train and register a model
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging(snapshot_directory=None)
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('Diabetes_data/diabetes.csv')

# Separate features and labels
X = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values
y = diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8883333333333333
# AUC: 0.8751156773968853
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('Diabetes_data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './diabetes-batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="diabetes-batch-data", target_path="diabetes-batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'diabetes-batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='diabetes-batch-data',
                                             description='diabetes batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# lgdatalakecf - Default = False
# lgstdatalakedev - Default = False
# azureml_globaldatasets - Default = False
# lgsqldwdev - Default = False
# workspaceblobstore - Default = True
# workspacefilestore - Default = False
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading diabetes-batch-data/1.csv
# Uploaded diabetes-batch-data/1.csv, 1 files out of an estimated total of 100
# Uploading diabetes-batch-data/10.csv
# Uploaded diabetes-batch-data/10.csv, 2 files out of an estimated total of 100
# Uploading diabetes-batch-data/100.csv
# Uploaded diabetes-batch-data/100.csv, 3 files out of an estimated total of 100
# Uploading diabetes-batch-data/11.csv
# Uploaded diabetes-batch-data/11.csv, 4 files out of an estimated total of 100
# Uploading diabetes-batch-data/12.csv
# Uploaded diabetes-batch-data/12.csv, 5 files out of an estimated total of 100
# Uploading diabetes-batch-data/13.csv
# Uploaded diabetes-batch-data/13.csv, 6 files out of an estimated total of 100
# Uploading diabetes-batch-data/14.csv
# Uploaded diabetes-batch-data/14.csv, 7 files out of an estimated total of 100
# Uploading diabetes-batch-data/15.csv
# Uploaded diabetes-batch-data/15.csv, 8 files out of an estimated total of 100
# Uploading diabetes-batch-data/16.csv
# Uploaded diabetes-batch-data/16.csv, 9 files out of an estimated total of 100
# Uploading diabetes-batch-data/17.csv
# Uploaded diabetes-batch-data/17.csv, 10 files out of an estimated total of 100
# Uploading diabetes-batch-data/18.csv
# Uploaded diabetes-batch-data/18.csv, 11 files out of an estimated total of 100
# Uploading diabetes-batch-data/19.csv
# Uploaded diabetes-batch-data/19.csv, 12 files out of an estimated total of 100
# Uploading diabetes-batch-data/2.csv
# Uploaded diabetes-batch-data/2.csv, 13 files out of an estimated total of 100
# Uploading diabetes-batch-data/20.csv
# Uploaded diabetes-batch-data/20.csv, 14 files out of an estimated total of 100
# Uploading diabetes-batch-data/21.csv
# Uploaded diabetes-batch-data/21.csv, 15 files out of an estimated total of 100
# Uploading diabetes-batch-data/22.csv
# Uploaded diabetes-batch-data/22.csv, 16 files out of an estimated total of 100
# Uploading diabetes-batch-data/23.csv
# Uploaded diabetes-batch-data/23.csv, 17 files out of an estimated total of 100
# Uploading diabetes-batch-data/24.csv
# Uploaded diabetes-batch-data/24.csv, 18 files out of an estimated total of 100
# Uploading diabetes-batch-data/25.csv
# Uploaded diabetes-batch-data/25.csv, 19 files out of an estimated total of 100
# Uploading diabetes-batch-data/26.csv
# Uploaded diabetes-batch-data/26.csv, 20 files out of an estimated total of 100
# Uploading diabetes-batch-data/27.csv
# Uploaded diabetes-batch-data/27.csv, 21 files out of an estimated total of 100
# Uploading diabetes-batch-data/28.csv
# Uploaded diabetes-batch-data/28.csv, 22 files out of an estimated total of 100
# Uploading diabetes-batch-data/29.csv
# Uploaded diabetes-batch-data/29.csv, 23 files out of an estimated total of 100
# Uploading diabetes-batch-data/3.csv
# Uploaded diabetes-batch-data/3.csv, 24 files out of an estimated total of 100
# Uploading diabetes-batch-data/31.csv
# Uploaded diabetes-batch-data/31.csv, 25 files out of an estimated total of 100
# Uploading diabetes-batch-data/32.csv
# Uploaded diabetes-batch-data/32.csv, 26 files out of an estimated total of 100
# Uploading diabetes-batch-data/33.csv
# Uploaded diabetes-batch-data/33.csv, 27 files out of an estimated total of 100
# Uploading diabetes-batch-data/34.csv
# Uploaded diabetes-batch-data/34.csv, 28 files out of an estimated total of 100
# Uploading diabetes-batch-data/35.csv
# Uploaded diabetes-batch-data/35.csv, 29 files out of an estimated total of 100
# Uploading diabetes-batch-data/36.csv
# Uploaded diabetes-batch-data/36.csv, 30 files out of an estimated total of 100
# Uploading diabetes-batch-data/37.csv
# Uploaded diabetes-batch-data/37.csv, 31 files out of an estimated total of 100
# Uploading diabetes-batch-data/38.csv
# Uploaded diabetes-batch-data/38.csv, 32 files out of an estimated total of 100
# Uploading diabetes-batch-data/39.csv
# Uploaded diabetes-batch-data/39.csv, 33 files out of an estimated total of 100
# Uploading diabetes-batch-data/4.csv
# Uploaded diabetes-batch-data/4.csv, 34 files out of an estimated total of 100
# Uploading diabetes-batch-data/40.csv
# Uploaded diabetes-batch-data/40.csv, 35 files out of an estimated total of 100
# Uploading diabetes-batch-data/41.csv
# Uploaded diabetes-batch-data/41.csv, 36 files out of an estimated total of 100
# Uploading diabetes-batch-data/42.csv
# Uploaded diabetes-batch-data/42.csv, 37 files out of an estimated total of 100
# Uploading diabetes-batch-data/43.csv
# Uploaded diabetes-batch-data/43.csv, 38 files out of an estimated total of 100
# Uploading diabetes-batch-data/44.csv
# Uploaded diabetes-batch-data/44.csv, 39 files out of an estimated total of 100
# Uploading diabetes-batch-data/45.csv
# Uploaded diabetes-batch-data/45.csv, 40 files out of an estimated total of 100
# Uploading diabetes-batch-data/47.csv
# Uploaded diabetes-batch-data/47.csv, 41 files out of an estimated total of 100
# Uploading diabetes-batch-data/5.csv
# Uploaded diabetes-batch-data/5.csv, 42 files out of an estimated total of 100
# Uploading diabetes-batch-data/50.csv
# Uploaded diabetes-batch-data/50.csv, 43 files out of an estimated total of 100
# Uploading diabetes-batch-data/53.csv
# Uploaded diabetes-batch-data/53.csv, 44 files out of an estimated total of 100
# Uploading diabetes-batch-data/30.csv
# Uploaded diabetes-batch-data/30.csv, 45 files out of an estimated total of 100
# Uploading diabetes-batch-data/46.csv
# Uploaded diabetes-batch-data/46.csv, 46 files out of an estimated total of 100
# Uploading diabetes-batch-data/48.csv
# Uploaded diabetes-batch-data/48.csv, 47 files out of an estimated total of 100
# Uploading diabetes-batch-data/49.csv
# Uploaded diabetes-batch-data/49.csv, 48 files out of an estimated total of 100
# Uploading diabetes-batch-data/51.csv
# Uploaded diabetes-batch-data/51.csv, 49 files out of an estimated total of 100
# Uploading diabetes-batch-data/52.csv
# Uploaded diabetes-batch-data/52.csv, 50 files out of an estimated total of 100
# Uploading diabetes-batch-data/54.csv
# Uploaded diabetes-batch-data/54.csv, 51 files out of an estimated total of 100
# Uploading diabetes-batch-data/55.csv
# Uploaded diabetes-batch-data/55.csv, 52 files out of an estimated total of 100
# Uploading diabetes-batch-data/56.csv
# Uploaded diabetes-batch-data/56.csv, 53 files out of an estimated total of 100
# Uploading diabetes-batch-data/57.csv
# Uploaded diabetes-batch-data/57.csv, 54 files out of an estimated total of 100
# Uploading diabetes-batch-data/58.csv
# Uploaded diabetes-batch-data/58.csv, 55 files out of an estimated total of 100
# Uploading diabetes-batch-data/59.csv
# Uploaded diabetes-batch-data/59.csv, 56 files out of an estimated total of 100
# Uploading diabetes-batch-data/6.csv
# Uploaded diabetes-batch-data/6.csv, 57 files out of an estimated total of 100
# Uploading diabetes-batch-data/60.csv
# Uploaded diabetes-batch-data/60.csv, 58 files out of an estimated total of 100
# Uploading diabetes-batch-data/61.csv
# Uploaded diabetes-batch-data/61.csv, 59 files out of an estimated total of 100
# Uploading diabetes-batch-data/62.csv
# Uploaded diabetes-batch-data/62.csv, 60 files out of an estimated total of 100
# Uploading diabetes-batch-data/63.csv
# Uploaded diabetes-batch-data/63.csv, 61 files out of an estimated total of 100
# Uploading diabetes-batch-data/64.csv
# Uploaded diabetes-batch-data/64.csv, 62 files out of an estimated total of 100
# Uploading diabetes-batch-data/65.csv
# Uploaded diabetes-batch-data/65.csv, 63 files out of an estimated total of 100
# Uploading diabetes-batch-data/66.csv
# Uploaded diabetes-batch-data/66.csv, 64 files out of an estimated total of 100
# Uploading diabetes-batch-data/67.csv
# Uploaded diabetes-batch-data/67.csv, 65 files out of an estimated total of 100
# Uploading diabetes-batch-data/68.csv
# Uploaded diabetes-batch-data/68.csv, 66 files out of an estimated total of 100
# Uploading diabetes-batch-data/69.csv
# Uploaded diabetes-batch-data/69.csv, 67 files out of an estimated total of 100
# Uploading diabetes-batch-data/7.csv
# Uploaded diabetes-batch-data/7.csv, 68 files out of an estimated total of 100
# Uploading diabetes-batch-data/70.csv
# Uploaded diabetes-batch-data/70.csv, 69 files out of an estimated total of 100
# Uploading diabetes-batch-data/71.csv
# Uploaded diabetes-batch-data/71.csv, 70 files out of an estimated total of 100
# Uploading diabetes-batch-data/72.csv
# Uploaded diabetes-batch-data/72.csv, 71 files out of an estimated total of 100
# Uploading diabetes-batch-data/73.csv
# Uploaded diabetes-batch-data/73.csv, 72 files out of an estimated total of 100
# Uploading diabetes-batch-data/74.csv
# Uploaded diabetes-batch-data/74.csv, 73 files out of an estimated total of 100
# Uploading diabetes-batch-data/75.csv
# Uploaded diabetes-batch-data/75.csv, 74 files out of an estimated total of 100
# Uploading diabetes-batch-data/76.csv
# Uploaded diabetes-batch-data/76.csv, 75 files out of an estimated total of 100
# Uploading diabetes-batch-data/77.csv
# Uploaded diabetes-batch-data/77.csv, 76 files out of an estimated total of 100
# Uploading diabetes-batch-data/78.csv
# Uploaded diabetes-batch-data/78.csv, 77 files out of an estimated total of 100
# Uploading diabetes-batch-data/79.csv
# Uploaded diabetes-batch-data/79.csv, 78 files out of an estimated total of 100
# Uploading diabetes-batch-data/8.csv
# Uploaded diabetes-batch-data/8.csv, 79 files out of an estimated total of 100
# Uploading diabetes-batch-data/80.csv
# Uploaded diabetes-batch-data/80.csv, 80 files out of an estimated total of 100
# Uploading diabetes-batch-data/81.csv
# Uploaded diabetes-batch-data/81.csv, 81 files out of an estimated total of 100
# Uploading diabetes-batch-data/82.csv
# Uploaded diabetes-batch-data/82.csv, 82 files out of an estimated total of 100
# Uploading diabetes-batch-data/83.csv
# Uploaded diabetes-batch-data/83.csv, 83 files out of an estimated total of 100
# Uploading diabetes-batch-data/84.csv
# Uploaded diabetes-batch-data/84.csv, 84 files out of an estimated total of 100
# Uploading diabetes-batch-data/85.csv
# Uploaded diabetes-batch-data/85.csv, 85 files out of an estimated total of 100
# Uploading diabetes-batch-data/86.csv
# Uploaded diabetes-batch-data/86.csv, 86 files out of an estimated total of 100
# Uploading diabetes-batch-data/87.csv
# Uploaded diabetes-batch-data/87.csv, 87 files out of an estimated total of 100
# Uploading diabetes-batch-data/88.csv
# Uploaded diabetes-batch-data/88.csv, 88 files out of an estimated total of 100
# Uploading diabetes-batch-data/89.csv
# Uploaded diabetes-batch-data/89.csv, 89 files out of an estimated total of 100
# Uploading diabetes-batch-data/9.csv
# Uploaded diabetes-batch-data/9.csv, 90 files out of an estimated total of 100
# Uploading diabetes-batch-data/90.csv
# Uploaded diabetes-batch-data/90.csv, 91 files out of an estimated total of 100
# Uploading diabetes-batch-data/91.csv
# Uploaded diabetes-batch-data/91.csv, 92 files out of an estimated total of 100
# Uploading diabetes-batch-data/92.csv
# Uploaded diabetes-batch-data/92.csv, 93 files out of an estimated total of 100
# Uploading diabetes-batch-data/93.csv
# Uploaded diabetes-batch-data/93.csv, 94 files out of an estimated total of 100
# Uploading diabetes-batch-data/94.csv
# Uploaded diabetes-batch-data/94.csv, 95 files out of an estimated total of 100
# Uploading diabetes-batch-data/95.csv
# Uploaded diabetes-batch-data/95.csv, 96 files out of an estimated total of 100
# Uploading diabetes-batch-data/96.csv
# Uploaded diabetes-batch-data/96.csv, 97 files out of an estimated total of 100
# Uploading diabetes-batch-data/97.csv
# Uploaded diabetes-batch-data/97.csv, 98 files out of an estimated total of 100
# Uploading diabetes-batch-data/98.csv
# Uploaded diabetes-batch-data/98.csv, 99 files out of an estimated total of 100
# Uploading diabetes-batch-data/99.csv
# Uploaded diabetes-batch-data/99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# **Important:** Change your-compute-cluster to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

#cluster_name = "your-compute-cluster"
cluster_name = "online-retail-fb"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# # Create a pipeline for batch inferencing
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model
    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []
    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        if not (np.isnan(data).any() | np.isinf(data).any()): # Check if it's nan or infinite. If it is skip
            prediction = model.predict(data.reshape(1, -1))
            # Append prediction to results
            resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
        else:
            continue
    return resultList
# Out:
# Overwriting batch_pipeline/batch_diabetes.py

# %% [markdown]
# Next we'll define a run context that includes the dependencies required by the script

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
# For parallel pipeline steps, you need azureml-core and azureml-dataprep[fuse]
cd = CondaDependencies.create(conda_packages=['scikit-learn','pip'],
                              pip_packages=['azureml-defaults','azureml-core','azureml-dataprep[fuse]'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.enabled = True
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named parallel_run_step.txt.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData

default_ds = ws.get_default_datastore()

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# **Note:** This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [4e318430][665e852d-4e9b-4519-8284-e16e8d6b80a9], (This step will run and generate new outputs)
# Submitted PipelineRun c7cd9412-8721-4717-8998-e58223017177
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/c7cd9412-8721-4717-8998-e58223017177?wsid=/subscriptions/bb4ff5a0-4884-4b27-93b4-b8294e6a7083/resourcegroups/lgarchitecturesetup-rg/workspaces/lg-aml-dev
# PipelineRunId: c7cd9412-8721-4717-8998-e58223017177
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/c7cd9412-8721-4717-8998-e58223017177?wsid=/subscriptions/bb4ff5a0-4884-4b27-93b4-b8294e6a7083/resourcegroups/lgarchitecturesetup-rg/workspaces/lg-aml-dev
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 472f32a4-83fb-4f57-90af-0592f0185462
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/472f32a4-83fb-4f57-90af-0592f0185462?wsid=/subscriptions/bb4ff5a0-4884-4b27-93b4-b8294e6a7083/resourcegroups/lgarchitecturesetup-rg/workspaces/lg-aml-dev
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_c510d7b18a255ebf091dd03fc02da90119f96114b28998e35c0181bb3ce43a88_d.txt
# ========================================================================================================================
# 2021-03-05T11:07:25Z Starting output-watcher...
# 2021-03-05T11:07:25Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_2a916f4728727b3b5b18dbee7e16a3e5
# Digest: sha256:68ffd55d5df309a0bda6ab9bb4fe2c3a1739a44786f2902f8f3bd785a61b3e4c
# Status: Image is up to date for viennaglobal.azurecr.io/azureml/azureml_2a916f4728727b3b5b18dbee7e16a3e5:latest
# viennaglobal.azurecr.io/azureml/azureml_2a916f4728727b3b5b18dbee7e16a3e5:latest
# 2021-03-05T11:07:28Z Check if container 472f32a4-83fb-4f57-90af-0592f0185462 already exist exited with 0,
#
# a5047250e5a3af75b2de384d4a14abda1960be4b0529e554c8c9127a529933ae
# 2021/03/05 11:07:30 Starting App Insight Logger for task:  containerSetup
# 2021/03/05 11:07:30 Version: 3.0.01509.0007 Branch: .SourceBranch Commit: 0d6b0ef
# 2021/03/05 11:07:30 Entered ContainerSetupTask - Preparing infiniband
# 2021/03/05 11:07:30 Starting infiniband setup
# 2021/03/05 11:07:30 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/05 11:07:30 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/05 11:07:30 sshd inside container not required for job, skipping setup.
# 2021/03/05 11:07:31 All App Insights Logs was send successfully
# 2021-03-05T11:07:31Z Starting docker container succeeded.
#
# Streaming azureml-logs/65_job_prep-tvmps_e8b11641480e9c88632973f76d23f7060fdb41392d3d1c1eccc8e63d41e284bd_d.txt
# ===============================================================================================================
# [2021-03-05T11:07:30.684303] Entering job preparation.
# [2021-03-05T11:07:31.579935] Starting job preparation.
# [2021-03-05T11:07:31.580102] Extracting the control code.
# [2021-03-05T11:07:31.604138] fetching and extracting the control code on master node.
# [2021-03-05T11:07:31.604178] Starting extract_project.
# [2021-03-05T11:07:31.604296] Starting to extract zip file.
# [2021-03-05T11:07:32.576704] Finished extracting zip file.
# [2021-03-05T11:07:32.751444] Using urllib.request Python 3.0 or later
# [2021-03-05T11:07:32.751524] Start fetching snapshots.
# [2021-03-05T11:07:32.751577] Start fetching snapshot.
# [2021-03-05T11:07:32.751596] Retrieving project from snapshot: 45c5ddf6-7d9b-434c-b317-6784e07f0450
# Starting the daemon thread to refresh tokens in background for process with pid = 39
# [2021-03-05T11:07:33.027384] Finished fetching snapshot.
# [2021-03-05T11:07:33.027431] Start fetching snapshot.
# [2021-03-05T11:07:33.027456] Retrieving project from snapshot: 7840cdc9-4321-41bd-98d8-c067eb54c735
# [2021-03-05T11:07:44.445709] Finished fetching snapshot.
# [2021-03-05T11:07:44.445742] Finished fetching snapshots.
# [2021-03-05T11:07:44.445852] Finished extract_project.
# [2021-03-05T11:07:44.460621] Finished fetching and extracting the control code.
# [2021-03-05T11:07:44.467150] Start run_history_prep.
# [2021-03-05T11:07:44.777025] Job preparation is complete.
# [2021-03-05T11:07:44.777126] Entering Data Context Managers in Sidecar
# [2021-03-05T11:07:44.780865] Running Sidecar prep cmd...
# [2021-03-05T11:07:44.888539] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462
# [2021-03-05T11:07:44.889470] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
#
# Streaming azureml-logs/65_job_prep-tvmps_c510d7b18a255ebf091dd03fc02da90119f96114b28998e35c0181bb3ce43a88_d.txt
# ===============================================================================================================
# [2021-03-05T11:07:32.181839] Entering job preparation.
# [2021-03-05T11:07:32.849898] Starting job preparation.
# [2021-03-05T11:07:32.849938] Extracting the control code.
# [2021-03-05T11:07:32.860464] Waiting for master node to finish fetching and extracting the control code. Will check again in 1 seconds.
# [2021-03-05T11:07:33.866751] Waiting for master node to finish fetching and extracting the control code. Will check again in 3 seconds.
# [2021-03-05T11:07:36.873387] Waiting for master node to finish fetching and extracting the control code. Will check again in 5 seconds.
# [2021-03-05T11:07:41.879922] Waiting for master node to finish fetching and extracting the control code. Will check again in 7 seconds.
# [2021-03-05T11:07:48.892425] Finished fetching and extracting the control code.
# [2021-03-05T11:07:48.892525] Not a master node. Skipping rest of the context managers.
# [2021-03-05T11:07:48.892550] Entering Data Context Managers in Sidecar
# [2021-03-05T11:07:48.893395] Running Sidecar prep cmd...
# [2021-03-05T11:07:48.962452] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462
# [2021-03-05T11:07:48.963883] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.21.0.post2 azureml-dataprep==2.9.1. Session id: df17a3df-f954-4803-add6-c01d5bb802cd. Run id: 472f32a4-83fb-4f57-90af-0592f0185462.
# Processing 'diabetes_batch'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'diabetes-batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "4d88b360-646e-4155-b9d0-79943252cd17",
#     "name": "diabetes-batch-data",
#     "version": 1,
#     "description": "diabetes batch data",
#     "workspace": "Workspace.create(name='lg-aml-dev', subscription_id='bb4ff5a0-4884-4b27-93b4-b8294e6a7083', resource_group='lgarchitecturesetup-rg')"
#   }
# }
# Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpsel3ya3q.
# Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpsel3ya3q as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpsel3ya3q
# Starting the daemon thread to refresh tokens in background for process with pid = 1
# Acquired lockfile /tmp/472f32a4-83fb-4f57-90af-0592f0185462-datastore.lock to downloading input data references
# [2021-03-05T11:08:00.451832] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-03-05T11:08:01.875180] Ran Sidecar prep cmd.
# [2021-03-05T11:08:01.875241] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/03/05 11:08:06 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/03/05 11:08:06 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-03-05T11:08:08.059130] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.23.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462/inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 107
# [2021-03-05T11:08:10.282606] Entering Run History Context Manager.
# [2021-03-05T11:08:11.808947] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462
# [2021-03-05T11:08:11.809289] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.23.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462/inferences', '--input_fds_0', 'diabetes_batch']
# [2021-03-05T11:08:11.809414] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.23.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462/inferences', '--input_fds_0', 'diabetes_batch']
#
# Starting the daemon thread to refresh tokens in background for process with pid = 107
#
#
# [2021-03-05T11:09:04.105117] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 3 items cleaning up...
# Cleanup took 0.5064923763275146 seconds
# [2021-03-05T11:09:05.166190] Finished context manager injector.
# 2021/03/05 11:09:06 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# 2021/03/05 11:09:06 Process Exiting with Code:  0
#
# Streaming azureml-logs/75_job_post-tvmps_e8b11641480e9c88632973f76d23f7060fdb41392d3d1c1eccc8e63d41e284bd_d.txt
# ===============================================================================================================
# [2021-03-05T11:09:07.900201] Entering job release
# [2021-03-05T11:09:09.571340] Starting job release
# [2021-03-05T11:09:09.571948] Logging experiment finalizing status in history service.
# [2021-03-05T11:09:09.572491] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 244
# [2021-03-05T11:09:09.575070] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-03-05T11:09:09.575187] job release stage : execute_job_release starting...
# [2021-03-05T11:09:09.575317] job release stage : copy_batchai_cached_logs starting...
# [2021-03-05T11:09:09.575363] job release stage : copy_batchai_cached_logs completed...
# [2021-03-05T11:09:09.657373] Entering context manager injector.
# [2021-03-05T11:09:09.832460] job release stage : send_run_telemetry starting...
# [2021-03-05T11:09:09.861874] job release stage : execute_job_release completed...
# [2021-03-05T11:09:09.899595] job release stage : upload_datastore completed...
# [2021-03-05T11:09:10.101924] get vm size and vm region successfully.
# [2021-03-05T11:09:10.118106] get compute meta data successfully.
# [2021-03-05T11:09:10.407670] post artifact meta request successfully.
# [2021-03-05T11:09:10.474004] upload compute record artifact successfully.
# [2021-03-05T11:09:10.687076] job release stage : send_run_telemetry completed...
# [2021-03-05T11:09:10.687371] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-03-05T11:09:10.687503] Running Sidecar release cmd...
# [2021-03-05T11:09:10.701197] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpys9pfu_6.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpys9pfu_6.
# Exit __exit__ of DatasetContextManager
# [2021-03-05T11:09:10.959027] Removing absolute paths from host...
# [2021-03-05T11:09:11.115285] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-03-05T11:09:12.014681] Ran Sidecar release cmd.
# [2021-03-05T11:09:12.014736] Job release is complete
#
# Streaming azureml-logs/75_job_post-tvmps_c510d7b18a255ebf091dd03fc02da90119f96114b28998e35c0181bb3ce43a88_d.txt
# ===============================================================================================================
# [2021-03-05T11:09:08.246594] Entering job release
# [2021-03-05T11:09:09.561823] job release stage : copy_batchai_cached_logs starting...
# [2021-03-05T11:09:09.561871] job release stage : copy_batchai_cached_logs completed...
# [2021-03-05T11:09:09.561900] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-03-05T11:09:09.562606] Running Sidecar release cmd...
# [2021-03-05T11:09:09.571742] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpsel3ya3q.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpsel3ya3q.
# Exit __exit__ of DatasetContextManager
# [2021-03-05T11:09:09.799933] Removing absolute paths from host...
# [2021-03-05T11:09:09.979465] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-03-05T11:09:10.572054] Ran Sidecar release cmd.
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '472f32a4-83fb-4f57-90af-0592f0185462', 'target': 'online-retail-fb', 'status': 'Completed', 'startTimeUtc': '2021-03-05T11:07:21.696992Z', 'endTimeUtc': '2021-03-05T11:09:32.671862Z', 'properties': {'ContentSnapshotId': '45c5ddf6-7d9b-434c-b317-6784e07f0450', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '665e852d-4e9b-4519-8284-e16e8d6b80a9', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '4e318430', 'azureml.pipelinerunid': 'c7cd9412-8721-4717-8998-e58223017177', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': '4d88b360-646e-4155-b9d0-79943252cd17'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.23.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'online-retail-fb', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/472f32a4-83fb-4f57-90af-0592f0185462/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '4d88b360-646e-4155-b9d0-79943252cd17', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2021-03-04T14:55:52Z_80baf4ab', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.23.0', 'azureml-core~=1.23.0', 'azureml-dataprep[fuse]']}, 'scikit-learn', 'pip'], 'name': 'azureml_458f08544b7a2a7a47f7713ce4b1cde4'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'c7cd9412-8721-4717-8998-e58223017177', 'status': 'Completed', 'startTimeUtc': '2021-03-05T11:06:48.734431Z', 'endTimeUtc': '2021-03-05T11:09:38.869567Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://lgstmldev.blob.core.windows.net/azureml/ExperimentRun/dcid.c7cd9412-8721-4717-8998-e58223017177/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=STS7fiWmiy1XLb8ZwpOjzVyVQlGAfy%2FQGxMYv5JbbXg%3D&st=2021-03-05T10%3A59%3A40Z&se=2021-03-05T19%3A09%3A40Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://lgstmldev.blob.core.windows.net/azureml/ExperimentRun/dcid.c7cd9412-8721-4717-8998-e58223017177/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=aqMci5qk%2FgI0NQ4QUZtsdxmbB2mcEqM5t%2BSN1dEMBEQ%3D&st=2021-03-05T10%3A59%3A40Z&se=2021-03-05T19%3A09%3A40Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://lgstmldev.blob.core.windows.net/azureml/ExperimentRun/dcid.c7cd9412-8721-4717-8998-e58223017177/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=tCGQLdAT0Dp3rPrgzPVAXgIIZztdDDSBOLCXKQsz40Y%3D&st=2021-03-05T10%3A59%3A40Z&se=2021-03-05T19%3A09%3A40Z&sp=r'}, 'submittedBy': 'Felicity Borg'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0   63.csv           0
# 1   64.csv           0
# 2   65.csv           0
# 3   66.csv           0
# 4   67.csv           0
# 5   22.csv           0
# 6   23.csv           1
# 7   24.csv           0
# 8   25.csv           1
# 9   26.csv           1
# 10  18.csv           1
# 11  19.csv           0
# 12   2.csv           1
# 13  20.csv           1
# 14  21.csv           0
# 15  90.csv           0
# 16  91.csv           0
# 17  92.csv           1
# 18  93.csv           0
# 19  94.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: ef7caba5-1820-4a95-ae00-4140aaf835f9,
# Status: Active,
# Endpoint: https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/bb4ff5a0-4884-4b27-93b4-b8294e6a7083/resourceGroups/lgarchitecturesetup-rg/providers/Microsoft.MachineLearningServices/workspaces/lg-aml-dev/PipelineRuns/PipelineSubmit/ef7caba5-1820-4a95-ae00-4140aaf835f9)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/bb4ff5a0-4884-4b27-93b4-b8294e6a7083/resourceGroups/lgarchitecturesetup-rg/providers/Microsoft.MachineLearningServices/workspaces/lg-aml-dev/PipelineRuns/PipelineSubmit/ef7caba5-1820-4a95-ae00-4140aaf835f9

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# **Note:** A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# 'e841907c-b222-4072-b03b-ab4bc004041a'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: e841907c-b222-4072-b03b-ab4bc004041a
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/e841907c-b222-4072-b03b-ab4bc004041a?wsid=/subscriptions/bb4ff5a0-4884-4b27-93b4-b8294e6a7083/resourcegroups/lgarchitecturesetup-rg/workspaces/lg-aml-dev
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 7dbdc20c-767a-4697-b756-641ab2210564
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/7dbdc20c-767a-4697-b756-641ab2210564?wsid=/subscriptions/bb4ff5a0-4884-4b27-93b4-b8294e6a7083/resourcegroups/lgarchitecturesetup-rg/workspaces/lg-aml-dev
# StepRun( batch-score-diabetes ) Status: NotStarted
#
# Streaming azureml-logs/75_job_post-tvmps_c510d7b18a255ebf091dd03fc02da90119f96114b28998e35c0181bb3ce43a88_d.txt
# ===============================================================================================================
# [2021-03-05T11:09:08.246594] Entering job release
# [2021-03-05T11:09:09.561823] job release stage : copy_batchai_cached_logs starting...
# [2021-03-05T11:09:09.561871] job release stage : copy_batchai_cached_logs completed...
# [2021-03-05T11:09:09.561900] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-03-05T11:09:09.562606] Running Sidecar release cmd...
# [2021-03-05T11:09:09.571742] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/mounts/workspaceblobstore/azureml/472f32a4-83fb-4f57-90af-0592f0185462
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpsel3ya3q.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/lg-aml-dev/azureml/472f32a4-83fb-4f57-90af-0592f0185462/wd/tmpsel3ya3q.
# Exit __exit__ of DatasetContextManager
# [2021-03-05T11:09:09.799933] Removing absolute paths from host...
# [2021-03-05T11:09:09.979465] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-03-05T11:09:10.572054] Ran Sidecar release cmd.
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '7dbdc20c-767a-4697-b756-641ab2210564', 'target': 'online-retail-fb', 'status': 'Completed', 'startTimeUtc': '2021-03-05T11:11:53.476652Z', 'endTimeUtc': '2021-03-05T11:11:56.637265Z', 'properties': {'azureml.reusedrunid': '472f32a4-83fb-4f57-90af-0592f0185462', 'azureml.reusednodeid': '4e318430', 'azureml.reusedpipeline': 'c7cd9412-8721-4717-8998-e58223017177', 'azureml.reusedpipelinerunid': 'c7cd9412-8721-4717-8998-e58223017177', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '4e318430', 'ContentSnapshotId': '45c5ddf6-7d9b-434c-b317-6784e07f0450', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '665e852d-4e9b-4519-8284-e16e8d6b80a9', 'azureml.pipelinerunid': 'e841907c-b222-4072-b03b-ab4bc004041a', 'azureml.pipelineid': 'ef7caba5-1820-4a95-ae00-4140aaf835f9', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.23.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'online-retail-fb', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/472f32a4-83fb-4f57-90af-0592f0185462/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': '4d88b360-646e-4155-b9d0-79943252cd17', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2021-03-04T14:55:52Z_80baf4ab', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults~=1.23.0', 'azureml-core~=1.23.0', 'azureml-dataprep[fuse]']}, 'scikit-learn', 'pip'], 'name': 'azureml_458f08544b7a2a7a47f7713ce4b1cde4'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': None, 'processCount': None}, 'hdi': {'yarnDeployM ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'e841907c-b222-4072-b03b-ab4bc004041a', 'status': 'Completed', 'startTimeUtc': '2021-03-05T11:11:48.54979Z', 'endTimeUtc': '2021-03-05T11:11:57.065158Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': 'ef7caba5-1820-4a95-ae00-4140aaf835f9'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://lgstmldev.blob.core.windows.net/azureml/ExperimentRun/dcid.e841907c-b222-4072-b03b-ab4bc004041a/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=QxOaQ13izl44%2F33ePBUQ7QxLSR2Jy3gdOkZq%2FxPqeA8%3D&st=2021-03-05T11%3A01%3A58Z&se=2021-03-05T19%3A11%3A58Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://lgstmldev.blob.core.windows.net/azureml/ExperimentRun/dcid.e841907c-b222-4072-b03b-ab4bc004041a/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=Vryokci7K%2B%2FHcTby%2BbbchP82rW%2BaAztYmWRId9%2Bw7Qc%3D&st=2021-03-05T11%3A01%3A58Z&se=2021-03-05T19%3A11%3A58Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://lgstmldev.blob.core.windows.net/azureml/ExperimentRun/dcid.e841907c-b222-4072-b03b-ab4bc004041a/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=EkrYuBsDKjc%2BZBE3IFxz6%2BSNPDTUuz26CBDzMFTTxos%3D&st=2021-03-05T11%3A01%3A58Z&se=2021-03-05T19%3A11%3A58Z&sp=r'}, 'submittedBy': 'Felicity Borg'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#       File  Prediction
# 0   63.csv           0
# 1   64.csv           0
# 2   65.csv           0
# 3   66.csv           0
# 4   67.csv           0
# 5   22.csv           0
# 6   23.csv           1
# 7   24.csv           0
# 8   25.csv           1
# 9   26.csv           1
# 10  18.csv           1
# 11  19.csv           0
# 12   2.csv           1
# 13  20.csv           1
# 14  21.csv           0
# 15  90.csv           0
# 16  91.csv           0
# 17  92.csv           1
# 18  93.csv           0
# 19  94.csv           0

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information:** For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
